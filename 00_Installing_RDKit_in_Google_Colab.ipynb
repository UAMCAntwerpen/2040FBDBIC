# %% [markdown]
# <a href="https://colab.research.google.com/github/UAMCAntwerpen/2040FBDBIC/blob/main/00_Installing_RDKit_in_Google_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install rdkit-pypi
# Out:
# ...
#      |████████████████████████████████| 18.6 MB 1.2 MB/s
# ...
